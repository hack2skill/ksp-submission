# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('BANK_STATEMENT.csv')

# %%
maxValues = df.max()

# %%
maxValues
# Out:
# Unnamed: 0                                116196
# Account No                          409000611074
# DATE                                  2019-03-05
# TRANSACTION DETAILS    ZEN LEFIN PVT LTD170206BA
# CHQ.NO.                                 874525.0
# VALUE DATE                            2019-03-05
# WITHDRAWAL AMT                      448207223.14
# DEPOSIT AMT                          544800000.0
# BALANCE AMT                            8500000.0
# A                                            sbi
# B                                           visa
# C                                       national
# D                                            tax
# E                                         direct
# dtype: object

# %%
df[df['DEPOSIT AMT']==df['DEPOSIT AMT'].max()]
# Out:
#        Unnamed: 0    Account No        DATE        TRANSACTION DETAILS  \
# 41234       13592  409000438620  2016-02-25  GOLD LABEL INVESTMENTS (P
#
#        CHQ.NO.  VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT  BALANCE AMT    A  \
# 41234      NaN  2016-02-25             NaN  544800000.0  -1514640.02  0.0
#
#          B    C    D    E
# 41234  0.0  0.0  0.0  0.0

# %%
df[df['DEPOSIT AMT']==df['DEPOSIT AMT'].min()]
# Out:
#        Unnamed: 0    Account No        DATE               TRANSACTION DETAILS  \
# 9720        10592  409000493210  2018-10-15  Indiaforensic RUPAY STL INTC1310
# 10370        8285  409000493210  2018-07-06  Indiaforensic  RUPAY SETT 050718
# 12443       10037  409000493210  2018-09-27  Indiaforensic RUPAY STL INTC2709
# 18983       11450  409000493210  2018-11-17  Indiaforensic RUPAY STL INTC1711
# 19857       11814  409000493210  2018-12-11  Indiaforensic RUPAY STL INTC1112
# 20484       11398  409000493210  2018-11-15  Indiaforensic RUPAY STL INTC1511
# 22236       13591  409000493210  2019-03-05  Indiaforensic RUP STL INTC050319
# 31034        9514  409000493210  2018-09-10  Indiaforensic RUPAY STL INTC1009
# 34546       11956  409000493210  2018-12-13  Indiaforensic RUPAY STL INTC1312
# 36348       10148  409000493210  2018-10-01  Indiaforensic RUPAY STL INTC3009
# 46648       13070  409000493210  2019-02-05  Indiaforensic RUP STL INTC050219
#
# ...

# %%
df[df['BALANCE AMT']==df['BALANCE AMT'].max()]
# Out:
#        Unnamed: 0    Account No        DATE         TRANSACTION DETAILS  \
# 11304           9  409000611074  2017-08-16  FDRL/INTERNAL FUND TRANSFE
#
#        CHQ.NO.  VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT  BALANCE AMT     A  \
# 11304      NaN  2017-08-16             NaN     500000.0    8500000.0  fdrl
#
#          B         C    D    E
# 11304  0.0  internal  0.0  0.0

# %%
df[df['BALANCE AMT']==df['BALANCE AMT'].min()]
# Out:
#        Unnamed: 0  Account No        DATE        TRANSACTION DETAILS  CHQ.NO.  \
# 21007       36314     1196711  2017-04-03  NEFT CITIN17763135036PAYU      NaN
#
#        VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT   BALANCE AMT    A     B    C  \
# 21007  2017-03-31             NaN     19850.33 -2.045181e+09  0.0  neft  0.0
#
#          D    E
# 21007  0.0  0.0

# %%
df[df['WITHDRAWAL AMT']==df['WITHDRAWAL AMT'].max()]
# Out:
#        Unnamed: 0  Account No        DATE        TRANSACTION DETAILS  CHQ.NO.  \
# 33100       36586     1196711  2017-05-26  Loan Recovery For90900003      NaN
#
#        VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT   BALANCE AMT    A    B     C  \
# 33100  2017-05-26    4.482072e+08          NaN -2.036201e+09  0.0  0.0  loan
#
#          D    E
# 33100  0.0  0.0

# %%
df[df['WITHDRAWAL AMT']==df['WITHDRAWAL AMT'].min()]
# Out:
#        Unnamed: 0    Account No        DATE               TRANSACTION DETAILS  \
# 44770        9302  409000493210  2018-08-24  Indiaforensic  RUPAY SETT 240818
#
#        CHQ.NO.  VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT   BALANCE AMT  \
# 44770      NaN  2018-08-24            0.01          NaN -5.443083e+08
#
#                    A      B    C    D    E
# 44770  indiaforensic  rupay  0.0  0.0  0.0

# %%
df[df['DATE']==df['DATE'].max()]
# Out:
#        Unnamed: 0    Account No        DATE               TRANSACTION DETAILS  \
# 885         86335       1196428  2019-03-05        FDRL/INTERNAL FUND TRANSFE
# 1098        13571  409000493210  2019-03-05  Indiaforensic NFS SETT 02-03-201
# 4231        27033  409000438620  2019-03-05         AEPS GST INC DT 03-04-201
# 4237       116191  409000362497  2019-03-05         NEFT/000069178432/MEHAR E
# 4780         7569  409000438611  2019-03-05  ICA 17825 Indiaforensic MC DOM 0
# 5620        27045  409000438620  2019-03-05         MICRO ATM GST DATED 05031
# 6312         7570  409000438611  2019-03-05  Indiaforensic VISA ACQ DOM040319
# 7356        27022  409000438620  2019-03-05   Indiaforensic AEPS NPCI WDL SET
# 7708        86353       1196428  2019-03-05        FDRL/INTERNAL FUND TRANSFE
# 8809         7574  409000438611  2019-03-05        FDRL/INTERNAL FUND TRANSFE
# 12805       86339       1196428  2019-03-05        FDRL/NATIONAL ELECTRONIC F
# ...

# %%
df[df['DATE']==df['DATE'].min()]
# Out:
#        Unnamed: 0  Account No        DATE               TRANSACTION DETAILS  \
# 532         37590     1196428  2015-01-02  DSB CASH PICKP IndiaforensicMET0
# 1001        37587     1196428  2015-01-02         CHQ DEP/252243/OWDEL1/SBI
# 3629        37584     1196428  2015-01-02         CHQ DEP/45811/OWDEL1/BARB
# 12962       37589     1196428  2015-01-02      RTGS/YESBH15002745737/Indfor
# 23661       37586     1196428  2015-01-02         CHQ DEP/252242/OWDEL1/SBI
# 28540       37588     1196428  2015-01-02         RTGS CHARGES AND STAX/RAT
# 30817       27047     1196711  2015-01-02           436418596193 - REVERSAL
#
#        CHQ.NO.  VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT   BALANCE AMT       A  \
# 532        NaN  2015-01-02             NaN    1500000.0 -1.588826e+09     dsb
# 1001       NaN  2015-01-02             NaN      25000.0 -1.584826e+09     sbi
# 3629       NaN  2015-01-02             NaN      15000.0 -1.584901e+09     0.0
# ...
