# %%
import pandas as pd
import re
# Out:
# C:\Users\siddh\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\siddh\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\siddh\anaconda3\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
import html2text

# %%
import urllib.request
HtmlFile = open('afjal raja soa.htm', 'r', encoding='utf-8')
source_code = HtmlFile.read()

# %%
s = html2text.html2text(source_code).replace('\r', '')

# %%
res = re.sub(' +', ' ', s)

# %%
# res

# %%
df = pd.read_csv('data.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9600/2837220152.py in <module>
# ----> 1 df = pd.read_csv('data.txt')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#open text file
text_file = open("data.txt", "w")
 
#write string to file
text_file.write(res)
 
#close file
text_file.close()

# %%
df

# %%
res = res.replace(' ',',')

# %%
res = res[1:]

# %%
import tabula
# Read a PDF File
df = tabula.read_pdf("UNITED services..pdf", pages='all')[0]
# convert PDF into CSV

print(df)

# %%
tabula.convert_into("UNITED services..pdf", "united1.csv", output_format="csv", pages='1')
# Out:
# Got stderr: Feb 04, 2023 7:27:22 PM org.apache.pdfbox.contentstream.operator.text.SetFontAndSize process
# WARNING: font 'Helvetica-Bold' not found in resources
# Feb 04, 2023 7:27:22 PM org.apache.pdfbox.contentstream.operator.text.SetFontAndSize process
# WARNING: font 'Helvetica' not found in resources
# Feb 04, 2023 7:27:22 PM org.apache.pdfbox.contentstream.operator.text.SetFontAndSize process
# WARNING: font 'Helvetica-Bold' not found in resources
# Feb 04, 2023 7:27:22 PM org.apache.pdfbox.contentstream.operator.text.SetFontAndSize process
# WARNING: font 'Helvetica' not found in resources
# Feb 04, 2023 7:27:22 PM org.apache.pdfbox.contentstream.operator.text.SetFontAndSize process
# WARNING: font 'Helvetica-Bold' not found in resources
# Feb 04, 2023 7:27:22 PM org.apache.pdfbox.contentstream.operator.text.SetFontAndSize process
# WARNING: font 'Helvetica' not found in resources
# Feb 04, 2023 7:27:22 PM org.apache.pdfbox.contentstream.operator.text.SetFontAndSize process
# ...

# %%
tabula.convert_into("UNITED services..pdf", "united2.csv", output_format="csv", pages='2')

# %%
tabula.convert_into("UNITED services..pdf", "united3.csv", output_format="csv", pages='3')

# %%
tabula.convert_into("UNITED services..pdf", "united4.csv", output_format="csv", pages='4')

# %%
tabula.convert_into("UNITED services..pdf", "united5.csv", output_format="csv", pages='5')

# %%
df1 = pd.read_csv('united1.csv')

# %%
df2 = pd.read_csv('united2.csv')
df3 = pd.read_csv('united3.csv')
df4 = pd.read_csv('united4.csv')
df5 = pd.read_csv('united5.csv')

# %%
df1+df2+df3+df4+df5
# Out:
#    BALANCE CREDITS DEBITS                                        DESCRIPTION  \
# 0      NaN     NaN    NaN  B/F ...VIKASPURIVIKASPURIATD:0100602748:800025...
# 1      NaN     NaN    NaN  CHEQUE DEPOSIT DELHI-SBINEFT CR-SBIN0016120-UN...
# 2      NaN     NaN    NaN  ATW:0100602748:DWARKA MORE:+YBLUNITED SERVICES...
# 3      NaN     NaN    NaN  DWARKA MOREDWARKA MOREATW:0100602748:VIKASPURI...
# 4      NaN     NaN    NaN  ATW:0100602748:DWARKA MORE:+YBLVIKASPURIVIKASP...
# ..     ...     ...    ...                                                ...
# 74     NaN     NaN    NaN                                                NaN
# 75     NaN     NaN    NaN                                                NaN
# 76     NaN     NaN    NaN                                                NaN
# 77     NaN     NaN    NaN                                                NaN
# 78     NaN     NaN    NaN                                                NaN
#
# ...

# %%
df_main = pd.concat([df1, df2,df3,df4,df5], axis=0)

# %%
df_main.drop(['Unnamed: 3'], axis=1)
# Out:
#        TXN DATE   VALUE DATE                          DESCRIPTION  \
# 0   01-JAN-2016  01-JAN-2016                              B/F ...
# 1   28-APR-2017  29-APR-2017             CHEQUE DEPOSIT DELHI-SBI
# 2   06-MAY-2017  06-MAY-2017      ATW:0100602748:DWARKA MORE:+YBL
# 3           NaN          NaN               DWARKA MOREDWARKA MORE
# 4   06-MAY-2017  06-MAY-2017      ATW:0100602748:DWARKA MORE:+YBL
# ..          ...          ...                                  ...
# 12          NaN          NaN            ACCOUNTS-BARBH17158491788
# 13  07-JUN-2017  07-JUN-2017                          IMPS/MANISH
# 14          NaN          NaN  SHARMAMANISH/XXX1778/RRN:7158176987
# 15          NaN          NaN                                  58/
# 16  08-JUN-2017  08-JUN-2017                   CASH DEP-MANJALPUR
#
#        REFERENCE     DEBITS    CREDITS     BALANCE
# 0            NaN       0.00       0.00        0.00
# 1   2.118100e+04       0.00  50,000.00   50,000.00
# ...

# %%
df_main.reset_index()
# Out:
#      index     TXN DATE   VALUE DATE                          DESCRIPTION  \
# 0        0  01-JAN-2016  01-JAN-2016                              B/F ...
# 1        1  28-APR-2017  29-APR-2017             CHEQUE DEPOSIT DELHI-SBI
# 2        2  06-MAY-2017  06-MAY-2017      ATW:0100602748:DWARKA MORE:+YBL
# 3        3          NaN          NaN               DWARKA MOREDWARKA MORE
# 4        4  06-MAY-2017  06-MAY-2017      ATW:0100602748:DWARKA MORE:+YBL
# ..     ...          ...          ...                                  ...
# 299     12          NaN          NaN            ACCOUNTS-BARBH17158491788
# 300     13  07-JUN-2017  07-JUN-2017                          IMPS/MANISH
# 301     14          NaN          NaN  SHARMAMANISH/XXX1778/RRN:7158176987
# 302     15          NaN          NaN                                  58/
# 303     16  08-JUN-2017  08-JUN-2017                   CASH DEP-MANJALPUR
#
#         REFERENCE     DEBITS    CREDITS     BALANCE  Unnamed: 3
# ...

# %%
df_main.to_csv('united.csv')

# %%
import camelot
tables = camelot.read_pdf('Vijaya.pdf',flavor='stream')
tables.export('X.csv', f='csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9600/2406726757.py in <module>
#       1 import camelot
# ----> 2 tables = camelot.read_pdf('Vijaya.pdf',flavor='stream')
#       3 tables.export('X.csv', f='csv')
#
# AttributeError: module 'camelot' has no attribute 'read_pdf'

# %%
import os
ls = os.listdir("Vijaya")

# %%
df = pd.read_csv('Vijaya/'+ls[1])

# %%
for i in ls:
    t_df = pd.read_csv('Vijaya/'+i)
    df = pd.concat([df,t_df],axis=0)

# %%
df.reset_index()
# Out:
#      index                                               Date  \
# 0        0  06/11/2018 NFSD/S1BW000213//15:07:35/831015008206
# 1        1  06/11/2018 NFSD/S1BW000213//15:08:20/831015008235
# 2        2                                                NaN
# 3        3                                                NaN
# 4        4                                                NaN
# ..     ...                                                ...
# 221     41                 04/12/2018 APY-SI-90220-04/12/2018
# 222     42                                                NaN
# 223     43                                                NaN
# 224     44  04/12/2018 NFSD/S1BW000213//19:17:51/833819009872
# 225     45                                                NaN
#
#                                Transaction Particulars  Ch No      Debit  \
# 0                                                  NaN    NaN   9,923.60
# ...

# %%
df.to_csv('Vijaya.csv')

# %%
df.Date = df.Date.astype(str)

# %%
df = pd.DataFrame(df.Date.str.split(' ',1).tolist(),columns = ['Date','new Date'])

# %%
intro = intro[intro.find('Date'):]

# %%
intro
# Out:
# 'Date","Transaction Particulars","Ch No","Debit","Credit","Balance"\n"17/10/2018 BY CASH","","","","2,000.00","2,000.00"\n"20/10/2018 APY-SI-90220-20/10/2018","","","151.00","","1,849.00"\n"30/10/2018 NFSD/BWCW102106//08:24:30/830308028405","","","1,500.00","","349.00"\n"01/11/2018 UPI/830513567421/karan/UTIB/910010029790637/Pay to","","","","19,000.00","19,349.00"\n"01/11/2018 IMPS/830513336199/P2A/PTM/AMA GHARAMI/comments","","","","100.00","19,449.00"\n"01/11/2018 IMPS/830513336496/P2A/PTM/AMA GHARAMI/comments","","","","9,600.00","29,049.00"\n"","01/11/2018 IMPS/830513338488/P2A/PTM/AJESWARI NASKAR/comments","","","100.00","29,149.00"\n"","01/11/2018 IMPS/830513338858/P2A/PTM/AJESWARI NASKAR/comments","","","7,700.00","36,849.00"\n"01/11/2018 UPI/830513567452/karan/UTIB/910010029790637/Pay to","","","","3,000.00","39,849.00"\n"01/11/2018 NFSD/S1BW000213//14:25:42/830514030954","","","10,000.00","","29,849.00"\n"01/11/2018 NFSD/S1BW000213//14:26:14/830514030967","","","10,000.00",
# ...

# %%
#open text file
text_file = open("data.csv", "w")
 
#write string to file
text_file.write(intro)
 
#close file
text_file.close()

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                                                 Date"  \
# 0                                  17/10/2018 BY CASH
# 1                  20/10/2018 APY-SI-90220-20/10/2018
# 2   30/10/2018 NFSD/BWCW102106//08:24:30/830308028405
# 3   01/11/2018 UPI/830513567421/karan/UTIB/9100100...
# 4   01/11/2018 IMPS/830513336199/P2A/PTM/AMA GHARA...
# 5   01/11/2018 IMPS/830513336496/P2A/PTM/AMA GHARA...
# 6                                                 NaN
# 7                                                 NaN
# 8   01/11/2018 UPI/830513567452/karan/UTIB/9100100...
# 9   01/11/2018 NFSD/S1BW000213//14:25:42/830514030954
# 10  01/11/2018 NFSD/S1BW000213//14:26:14/830514030967
# 11  01/11/2018 NFSD/S1BW000213//14:26:46/830514030981
# 12  01/11/2018 POS/JAMTARA J/DIGITAL TELE/83051884...
# 13  02/11/2018 IMPS/830613087904/P2A/PTM/HAYRAN MO...
# 14  02/11/2018 IMPS/830613088132/P2A/PTM/HAYRAN MO...
# 15  02/11/2018 NFSD/GFNV000213//13:29:40/830613030111
# ...

# %%
#open text file
text_file = open("data.txt", "w")
 
#write string to file
text_file.write(st)
 
#close file
text_file.close()

# %%
pd.read_csv('data.txt')
# Out:
#                                                                   Date Transaction Particulars Ch No Debit Credit Balance
# 06/11/2018 |NFSD/S1BW000213//15:07:35/831015008... 923.60] 5                                                  480.20
# 06/11/2018 |NFSD/S1BW000213//15:08:20/831015008... NaN                                                           NaN
# 06/11/2018 |IMPS/831017082581/P2A/MWK/ne Mobikw... 056.60)                                                       NaN
# 06/11/2018 |IMPS/831017214710/P2A/PTM/EKH FAJLU... 056.60                                                        NaN
# 06/11/2018 |IMPS/831017216194/P2A/PTM/EKH FAJLU... 056.60                                                        NaN
# 06/11/2018 |IMPS/831017215615/P2A/PTM/EKH FAJLU... 056.60)                                                       NaN
# 06/11/2018 |IMPS/831017215914/P2A/PTM/EKH FAJLU... 456.60)                                                       NaN
# ...

# %%
# !pip install pdfminer
# Out:
# ...
#   Created wheel for pdfminer: filename=pdfminer-20191125-py3-none-any.whl size=6140091 sha256=46fa9d26680d17a46cb3c0997e75c06bfe4921c01ba4aec83b3bc17a3c32a8d8
#   Stored in directory: c:\users\siddh\appdata\local\pip\cache\wheels\d1\aa\48\370f83a970d62355a2a47d2d640094a64eea932c22edae1891
# Successfully built pdfminer
# ...

# %%
tabula.convert_into("Vijaya.pdf", "vij.csv", output_format="csv", pages='all')

# %%
pd.read_csv('vij.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9600/1546910280.py in <module>
# ----> 1 pd.read_csv('vij.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import pandas as pd
  
df = pd.read_csv('acc_state.rpt', delimiter='|')

# %%
df
# Out:
#    ------------------------------------------------------------------------------------------------------------------------------------
# 0   Date        Tran    Ref Num    Particulars    ...
# 1               Id                                ...
# 2   ----------------------------------------------...
# 3            Account Opening balance : Nil        ...
# 4            Brought Forward :                    ...
# 5   22-10-2014 S9368030 TCS        281862841585//S...
# 6   10-02-2015 S7113338            Int:16-10-2014/...
# 7   11-04-2015 S5052800 TCS        429777342311//M...
# 8   13-04-2015 BI330270            TO CASH        ...
# 9   20-06-2015 S2980518 TCS        490282132786//M...
# 10  22-06-2015 BI223976            TO CASH        ...
# 11  08-08-2015 S1960004            Int:01-02-2015/...
# 12  12-08-2015  S880374 TCS        536346550114//M...
# 13  14-08-2015 BI311008            TO CASH        ...
# 14  31-08-2015 BI332481            TO CASH        ...
# ...
